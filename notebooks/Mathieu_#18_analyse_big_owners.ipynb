# %% [markdown]
# # Analyse des plus gros owners :

# %% [markdown]
# #### Dans le but de retirer les outliers (c'est-à-dire les plus gros studios de productions) pour avoir une répartition assez équilibrée

# %%
pip install sqldf
# Out:
# Requirement already satisfied: sqldf in /Users/mathieudbt/.pyenv/versions/3.8.12/envs/steamator/lib/python3.8/site-packages (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import collections 
import sqldf

# %%
df = pd.read_csv('../raw_data/data_clean.csv')
df.head(3)
# Out:
#    steam_appid                       name release_date  english  \
# 0           10             Counter-Strike   2000-11-01        1
# 1           30              Day of Defeat   2003-05-01        1
# 2           50  Half-Life: Opposing Force   1999-11-01        1
#
#           developer publisher          platforms  \
# 0             Valve     Valve  windows;mac;linux
# 1             Valve     Valve  windows;mac;linux
# 2  Gearbox Software     Valve  windows;mac;linux
#
#                                           categories      genres  \
# 0  ['Multi-player', 'Online Multi-Player', 'Local...  ['Action']
# 1       ['Multi-player', 'Valve Anti-Cheat enabled']  ['Action']
# 2  ['Single-player', 'Multi-player', 'Valve Anti-...  ['Action']
#
#                             steamspy_tags  ...  world_war_i world_war_ii  \
# 0        ['Action', 'FPS', 'Multiplayer']  ...            0            0
# 1  ['FPS', 'World War II', 'Multiplayer']  ...            5          122
# 2             ['FPS', 'Action', 'Sci-fi']  ...            0            0
#
#    wrestling zombies e_sports owner_median owner_lower owner_upper  \
# 0          0       0      550   15000000.0    10000000    20000000
# 1          0       0        0    7500000.0     5000000    10000000
# 2          0       0        0    7500000.0     5000000    10000000
#
#        revenue has_a_website
# 0  107850000.0             0
# 1   29925000.0             1
# 2   29925000.0             0
#
# [3 rows x 396 columns]

# %%
df['developer'].nunique()
# Out:
# 17047

# %% [markdown]
# ## Classement des publishers par nombre de jeux produits

# %%
# Nombre de publishers uniques

df['publisher'].nunique()
# Out:
# 14312

# %%
# Obtenir le nombre de jeux produits par publisher => Output : {publisher : nombre de jeux produits}

pub_count = collections.Counter(df['publisher'])

# %%
# Classement des publishers dans l'ordre décroissant

best_pub = sorted([(v,k) for k,v in pub_count.items()],reverse=True)

# %%
best_pub_df = pd.DataFrame(best_pub, columns=['pub_nb_games','publisher'])
best_pub_df.head(20)
# Out:
#     pub_nb_games                   publisher
# 0            212              Big Fish Games
# 1            131              Strategy First
# 2            100                     Ubisoft
# 3             98                  THQ Nordic
# 4             96               Sekai Project
# 5             94             Choice of Games
# 6             88         Dagestan Technology
# 7             87            1C Entertainment
# 8             81                 Square Enix
# 9             77                        SEGA
# 10            77                      Degica
# 11            72             Plug In Digital
# 12            71             Slitherine Ltd.
# 13            71  KOEI TECMO GAMES CO., LTD.
# 14            71                    KISS ltd
# 15            69                 AGM PLAYISM
# 16            67               Artifex Mundi
# 17            65            Devolver Digital
# 18            64          Buka Entertainment
# 19            64                  Atriagames

# %%
best_pub_df.shape
# Out:
# (14312, 2)

# %%
final_df = pd.merge(df, best_pub_df, how="right", on="publisher")

# %%
final_df.columns
# Out:
# Index(['steam_appid', 'name', 'release_date', 'english', 'developer',
#        'publisher', 'platforms', 'categories', 'genres', 'steamspy_tags',
#        ...
#        'world_war_ii', 'wrestling', 'zombies', 'e_sports', 'owner_median',
#        'owner_lower', 'owner_upper', 'revenue', 'has_a_website',
#        'pub_nb_games'],
#       dtype='object', length=397)

# %%
publisher_df = final_df[['steam_appid','name','release_date','developer','publisher','pub_nb_games','owner_median']]

publisher_df
# Out:
#        steam_appid                                         name release_date  \
# 0             7340                                        Azada   2010-04-21
# 1            50910  Professor Fizzwizzle and the Molten Mystery   2010-04-21
# 2            50920                    Hidden Expedition: Amazon   2010-04-21
# 3            50930                   Hidden Expedition: Everest   2010-04-21
# 4            50940                   Hidden Expedition: Titanic   2010-04-21
# ...            ...                                          ...          ...
# 26862      1060770                    Die, zombie sausage, die!   2019-04-24
# 26863       858100                                    Grimshade   2019-03-26
# 26864       832420                                      ICED VR   2018-05-29
# 26865       659100                                      Skyfall   2017-07-28
# 26866       456780                    DUCATI - 90th Anniversary   2016-06-09
#
#               developer           publisher  pub_nb_games  owner_median
# 0        Big Fish Games      Big Fish Games           212       10000.0
# 1        Big Fish Games      Big Fish Games           212       10000.0
# 2        Big Fish Games      Big Fish Games           212       10000.0
# 3        Big Fish Games      Big Fish Games           212       10000.0
# 4        Big Fish Games      Big Fish Games           212       10000.0
# ...                 ...                 ...           ...           ...
# 26862        AuroraCorp     Aurora software             1       10000.0
# 26863          TALEROCK      Asterion Games             1       10000.0
# 26864      Anea_Duo_Dev        Anea_Duo_Dev             1       10000.0
# 26865    AYE Technology      AYE Technology             1       10000.0
# 26866  Milestone S.r.l.    Milestone S.r.l.             1       10000.0
#
# [26867 rows x 7 columns]

# %%
# On va considérer que les plus gros owners sont ceux qui ont une médiane des ventes à 75 000 000 min

final_df.owner_median.value_counts()
# Out:
# 10000.0        18529
# 35000.0         3018
# 75000.0         1675
# 150000.0        1367
# 350000.0        1240
# 750000.0         493
# 1500000.0        286
# 3500000.0        191
# 7500000.0         42
# 15000000.0        20
# 35000000.0         3
# 75000000.0         2
# 150000000.0        1
# Name: owner_median, dtype: int64

# %%
# Recenser les outliers qui ont un owner median > ou = 7 500 000 (soit 68 jeux)

pub_plus = publisher_df[publisher_df['owner_median']>=7500000]

# %%
pub_plus.sort_values(by='owner_median',ascending=False).head(40)
# Out:
#        steam_appid                              name release_date  \
# 4044           570                            Dota 2   2013-07-09
# 20149       578080     PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-
# 9888                         Perfect World Entertainment             4
# 4029                                               Valve            24
# 10496                             Activision;Aspyr (Mac)             4
# 10964  Square Enix;Feral Interactive (Mac);Feral Inte...             3
#
#        owner_median
# 12098     7500000.0
# 20615     7500000.0
# 20732     7500000.0
# 21683     7500000.0
# 13520     7500000.0
# 4040      7500000.0
# 11846     7500000.0
# 11216     7500000.0
# 4042      7500000.0
# 4038      7500000.0
# 4036      7500000.0
# 4033      7500000.0
# 6318      7500000.0
# 7672      7500000.0
# 7866      7500000.0
# 8297      7500000.0
# 8433      7500000.0
# 8571      7500000.0
# 411       7500000.0
# 9087      7500000.0
# 4031      7500000.0
# 9401      7500000.0
# 9402      7500000.0
# 4030      7500000.0
# 9888      7500000.0
# 4029      7500000.0
# 10496     7500000.0
# 10964     7500000.0

# %%
publisher_df['publisher'].nunique()
# Out:
# 14312

# %%
# Publishers ont sorti entre 1 et 5 jeux // >

publisher_df[publisher_df['pub_nb_games']>5].nunique()
# Out:
# steam_appid     8681
# name            8677
# release_date    2088
# developer       3293
# publisher        520
# pub_nb_games      59
# owner_median      13
# dtype: int64

# %%
desc = pd.read_csv('../raw_data/steam_description_data.csv')
desc.shape
# Out:
# (27334, 4)

# %%
publisher_df.shape
# Out:
# (26867, 7)

# %%
desc_mg = pd.merge(publisher_df, desc, how="inner", on="steam_appid")

# %%
desc_mg.shape
# Out:
# (26867, 10)

# %%
desc_mg
# Out:
#        steam_appid                                         name release_date  \
# 0             7340                                        Azada   2010-04-21
# 1            50910  Professor Fizzwizzle and the Molten Mystery   2010-04-21
# 2            50920                    Hidden Expedition: Amazon   2010-04-21
# 3            50930                   Hidden Expedition: Everest   2010-04-21
# 4            50940                   Hidden Expedition: Titanic   2010-04-21
# ...            ...                                          ...          ...
# 26862      1060770                    Die, zombie sausage, die!   2019-04-24
# 26863       858100                                    Grimshade   2019-03-26
# 26864       832420                                      ICED VR   2018-05-29
# 26865       659100                                      Skyfall   2017-07-28
# 26866       456780                    DUCATI - 90th Anniversary   2016-06-09
#
#               developer           publisher  pub_nb_games  owner_median  \
# 0        Big Fish Games      Big Fish Games           212       10000.0
# 1        Big Fish Games      Big Fish Games           212       10000.0
# 2        Big Fish Games      Big Fish Games           212       10000.0
# 3        Big Fish Games      Big Fish Games           212       10000.0
# 4        Big Fish Games      Big Fish Games           212       10000.0
# ...                 ...                 ...           ...           ...
# 26862        AuroraCorp     Aurora software             1       10000.0
# 26863          TALEROCK      Asterion Games             1       10000.0
# 26864      Anea_Duo_Dev        Anea_Duo_Dev             1       10000.0
# 26865    AYE Technology      AYE Technology             1       10000.0
# 26866  Milestone S.r.l.    Milestone S.r.l.             1       10000.0
#
#                                     detailed_description  \
# 0      Trapped in a magical puzzle book, the adventur...
# 1      <p>While on a well deserved vacation, Professo...
# 2      Big Fish Games Studios takes you on an Adventu...
# 3      Fresh from a successful exploration of the wre...
# 4      On April 14, 1912, the great steamship RMS Tit...
# ...                                                  ...
# 26862  Arcade for the little ones. Hold on to the tab...
# 26863  <img src="https://steamcdn-a.akamaihd.net/stea...
# 26864  This VR version of the game ICED, we have trie...
# 26865  <strong>Skyfall</strong> it is old school firs...
# 26866  From the creators of RIDE comes a spin-off ent...
#
#                                           about_the_game  \
# 0      Trapped in a magical puzzle book, the adventur...
# 1      <p>While on a well deserved vacation, Professo...
# 2      Big Fish Games Studios takes you on an Adventu...
# 3      Fresh from a successful exploration of the wre...
# 4      On April 14, 1912, the great steamship RMS Tit...
# ...                                                  ...
# 26862  Arcade for the little ones. Hold on to the tab...
# 26863  <img src="https://steamcdn-a.akamaihd.net/stea...
# 26864  This VR version of the game ICED, we have trie...
# 26865  <strong>Skyfall</strong> it is old school firs...
# 26866  From the creators of RIDE comes a spin-off ent...
#
#                                        short_description
# 0      Trapped in a magical puzzle book, the adventur...
# 1      While on a well deserved vacation, Professor F...
# 2      Big Fish Games Studios takes you on an Adventu...
# 3      Fresh from a successful exploration of the wre...
# 4      On April 14, 1912, the great steamship RMS Tit...
# ...                                                  ...
# 26862  Arcade for the little ones. Hold on to the tab...
# 26863  Grimshade is a party-based role-playing game i...
# 26864  The protagonist goes winter fishing on a lake ...
# 26865  2217. Distant future. We act as an engineer ni...
# 26866  From the creators of RIDE comes a spin-off ent...
#
# [26867 rows x 10 columns]

# %%
publisher_df
# Out:
#        steam_appid                                         name release_date  \
# 0             7340                                        Azada   2010-04-21
# 1            50910  Professor Fizzwizzle and the Molten Mystery   2010-04-21
# 2            50920                    Hidden Expedition: Amazon   2010-04-21
# 3            50930                   Hidden Expedition: Everest   2010-04-21
# 4            50940                   Hidden Expedition: Titanic   2010-04-21
# ...            ...                                          ...          ...
# 26862      1060770                    Die, zombie sausage, die!   2019-04-24
# 26863       858100                                    Grimshade   2019-03-26
# 26864       832420                                      ICED VR   2018-05-29
# 26865       659100                                      Skyfall   2017-07-28
# 26866       456780                    DUCATI - 90th Anniversary   2016-06-09
#
#               developer           publisher  pub_nb_games  owner_median
# 0        Big Fish Games      Big Fish Games           212       10000.0
# 1        Big Fish Games      Big Fish Games           212       10000.0
# 2        Big Fish Games      Big Fish Games           212       10000.0
# 3        Big Fish Games      Big Fish Games           212       10000.0
# 4        Big Fish Games      Big Fish Games           212       10000.0
# ...                 ...                 ...           ...           ...
# 26862        AuroraCorp     Aurora software             1       10000.0
# 26863          TALEROCK      Asterion Games             1       10000.0
# 26864      Anea_Duo_Dev        Anea_Duo_Dev             1       10000.0
# 26865    AYE Technology      AYE Technology             1       10000.0
# 26866  Milestone S.r.l.    Milestone S.r.l.             1       10000.0
#
# [26867 rows x 7 columns]

# %%
publisher_df.to_csv(r'../raw_data/publisher_df.csv', index = False)
