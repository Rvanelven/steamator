# %% [markdown]
# # Délimitation X et y

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
import numpy as np
from sklearn.model_selection import learning_curve
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import cross_val_score
import math
from tensorflow.keras import Sequential
from sklearn.linear_model import ElasticNetCV
from update_checker import update_check
from tpot.builtins import CombineDFs, StackingEstimator
from xgboost import XGBRegressor
from sklearn.linear_model import SGDRegressor
# Out:
# 2021-12-03 16:50:23.962836: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-03 16:50:23.962877: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/etienne/.pyenv/versions/3.8.12/envs/steamator/lib/python3.8/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
data = pd.read_csv("../raw_data/data_final_indé_small.csv")

# %%
data_price = data[data['price'] > 2 ]

# %%
data_price
# Out:
#        steam_appid                           name  \
# 0             4290       RACE: Caterham Expansion
# 2             7340                          Azada
# 3             9960                 Haunted House™
# 4             9970                   Star Raiders
# 5            10140  3D Ultra™ Minigolf Adventures
# ...            ...                            ...
# 18523      1065160                      Deatherem
# 18524      1065230                Room of Pandora
# 18526      1065650               Super Star Blast
# 18527      1066700     New Yankee 7: Deer Hunters
# 18528      1069460                      Rune Lord
#
#                                               top_5_tags   topic_0   topic_1  \
# 0      racing simulation relaxing realistic real_time...  0.015822  0.015822
# 2                 casual puzzle 1980s relaxing realistic  0.015666  0.307211
# 3      adventure 1980s relaxing realistic real_time_w...  0.015546  0.015546
# 4      action space 1980s realistic real_time_with_pause  0.016158  0.016158
# 5        sports mini_golf golf local_multiplayer science  0.015755  0.015755
# ...                                                  ...       ...       ...
# 18523  horror first_person survival_horror real_time_...  0.467192  0.015716
# 18524             adventure casual puzzle 1980s relaxing  0.015694  0.701810
# 18526             action casual 1980s relaxing realistic  0.015483  0.015483
# 18527          casual adventure 1980s relaxing realistic  0.015466  0.015466
# 18528          casual adventure 1980s relaxing realistic  0.015466  0.015466
#
#         topic_2   topic_3   topic_4   topic_5   topic_6  ...  english  price  \
# 0      0.015822  0.015822  0.015822  0.015822  0.015822  ...        1   3.99
# 2      0.015666  0.015666  0.015666  0.015666  0.015666  ...        1   6.99
# 3      0.015546  0.015546  0.015546  0.015546  0.015546  ...        1   4.79
# 4      0.016158  0.016158  0.016158  0.016158  0.016158  ...        1   6.99
# 5      0.136535  0.015755  0.015755  0.015755  0.015755  ...        1   6.99
# ...         ...       ...       ...       ...       ...  ...      ...    ...
# 18523  0.015716  0.015716  0.015716  0.015716  0.015716  ...        1   2.09
# 18524  0.015694  0.015694  0.015694  0.015694  0.015694  ...        1   2.09
# 18526  0.015483  0.015483  0.015483  0.015483  0.015483  ...        1   3.99
# 18527  0.015466  0.015466  0.015466  0.015466  0.015466  ...        1   5.19
# 18528  0.015466  0.015466  0.015466  0.015466  0.015466  ...        1   5.19
#
#        has_a_website  nb_review  owner_estimated       rating   popularity  \
# 0                  1          6           1248.0   424.233333   517.758333
# 2                  1         12           2496.0     7.012399     9.197810
# 3                  1         22           4576.0   215.087500   263.378125
# 4                  1         29           6032.0   209.787500   263.028125
# 5                  0         78          16224.0  1253.642857  1824.928571
# ...              ...        ...              ...          ...          ...
# 18523              0          4            832.0     5.450000     8.993750
# 18524              0          3            624.0     3.000000     3.000000
# 18526              1          1            208.0     4.600000    10.450000
# 18527              1          2            416.0    23.463964    29.301802
# 18528              1          4            832.0    21.097297    26.485135
#
#        score_descriptif  average_playtime  median_playtime
# 0                     4                 0                0
# 2                     1                 0                0
# 3                     3                 0                0
# 4                     2                 0                0
# 5                     6                 0                0
# ...                 ...               ...              ...
# 18523                 6                 0                0
# 18524                 1                 0                0
# 18526                 5                 0                0
# 18527                 2                 0                0
# 18528                 3                 0                0
#
# [13045 rows x 33 columns]

# %%
obj = data.isnull().sum()
for key,value in obj.iteritems():
    print(f'"{key}"')
# Out:
# "steam_appid"
# "name"
# "top_5_tags"
# "topic_0"
# "topic_1"
# "topic_2"
# "topic_3"
# "topic_4"
# "topic_5"
# "topic_6"
# "topic_7"
# "topic_8"
# "topic_9"
# "topic_10"
# "topic_11"
# "topic_12"
# "topic_13"
# "topic_14"
# "topic_15"
# "topic_16"
# "topic_17"
# "topic_18"
# "topic_19"
# "english"
# "price"
# "has_a_website"
# "nb_review"
# "owner_estimated"
# "rating"
# "popularity"
# "score_descriptif"
# "average_playtime"
# "median_playtime"

# %%
X = data_price.drop(columns=["steam_appid",
                        "name",
                       "top_5_tags",
                       "nb_review",
                       "owner_estimated",
                       "topic_7",
                       "rating",
                       "popularity",
                      "average_playtime",
                    "median_playtime"])
#X = data[['name']]
y = data_price['owner_estimated']

# %%
X.columns
# Out:
# Index(['topic_0', 'topic_1', 'topic_2', 'topic_3', 'topic_4', 'topic_5',
#        'topic_6', 'topic_8', 'topic_9', 'topic_10', 'topic_11', 'topic_12',
#        'topic_13', 'topic_14', 'topic_15', 'topic_16', 'topic_17', 'topic_18',
#        'topic_19', 'english', 'price', 'has_a_website', 'score_descriptif'],
#       dtype='object')

# %%
y
# Out:
# 0         1248.0
# 2         2496.0
# 3         4576.0
# 4         6032.0
# 5        16224.0
#           ...
# 18523      832.0
# 18524      624.0
# 18526      208.0
# 18527      416.0
# 18528      832.0
# Name: owner_estimated, Length: 13045, dtype: float64

# %%
X
# Out:
#         topic_0   topic_1   topic_2   topic_3   topic_4   topic_5   topic_6  \
# 0      0.015822  0.015822  0.015822  0.015822  0.015822  0.015822  0.015822
# 2      0.015666  0.307211  0.015666  0.015666  0.015666  0.015666  0.015666
# 3      0.015546  0.015546  0.015546  0.015546  0.015546  0.015546  0.015546
# 4      0.016158  0.016158  0.016158  0.016158  0.016158  0.016158  0.016158
# 5      0.015755  0.015755  0.136535  0.015755  0.015755  0.015755  0.015755
# ...         ...       ...       ...       ...       ...       ...       ...
# 18523  0.467192  0.015716  0.015716  0.015716  0.015716  0.015716  0.015716
# 18524  0.015694  0.701810  0.015694  0.015694  0.015694  0.015694  0.015694
# 18526  0.015483  0.015483  0.015483  0.015483  0.015483  0.015483  0.015483
# 18527  0.015466  0.015466  0.015466  0.015466  0.015466  0.015466  0.015466
# 18528  0.015466  0.015466  0.015466  0.015466  0.015466  0.015466  0.015466
#
#         topic_8   topic_9  topic_10  ...  topic_14  topic_15  topic_16  \
# 0      0.015822  0.015822  0.015822  ...  0.015822  0.015822  0.428065
# 2      0.015666  0.015666  0.015666  ...  0.015666  0.015666  0.015666
# 3      0.015546  0.015546  0.015546  ...  0.015546  0.015546  0.015546
# 4      0.016158  0.016158  0.016158  ...  0.016158  0.275846  0.016158
# 5      0.267618  0.154468  0.015755  ...  0.015755  0.015755  0.015755
# ...         ...       ...       ...  ...       ...       ...       ...
# 18523  0.249924  0.015716  0.015716  ...  0.015716  0.015716  0.015716
# 18524  0.015694  0.015694  0.015694  ...  0.015694  0.015694  0.015694
# 18526  0.015483  0.015483  0.015483  ...  0.015483  0.015483  0.015483
# 18527  0.015466  0.015466  0.015466  ...  0.015466  0.015466  0.015466
# 18528  0.015466  0.015466  0.015466  ...  0.015466  0.015466  0.015466
#
#        topic_17  topic_18  topic_19  english  price  has_a_website  \
# 0      0.015822  0.015822  0.015822        1   3.99              1
# 2      0.015666  0.015666  0.410797        1   6.99              1
# 3      0.015546  0.015546  0.704628        1   4.79              1
# 4      0.016158  0.016158  0.433305        1   6.99              1
# 5      0.015755  0.189293  0.015755        1   6.99              0
# ...         ...       ...       ...      ...    ...            ...
# 18523  0.015716  0.015716  0.015716        1   2.09              0
# 18524  0.015694  0.015694  0.015694        1   2.09              0
# 18526  0.015483  0.015483  0.705831        1   3.99              1
# 18527  0.015466  0.015466  0.706139        1   5.19              1
# 18528  0.015466  0.015466  0.706139        1   5.19              1
#
#        score_descriptif
# 0                     4
# 2                     1
# 3                     3
# 4                     2
# 5                     6
# ...                 ...
# 18523                 6
# 18524                 1
# 18526                 5
# 18527                 2
# 18528                 3
#
# [13045 rows x 23 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Baseline model

# %%
resultat = 0
for i in y:
    score = (10000-i)**2
    resultat += score
print(resultat/len(y))
print(math.sqrt(resultat/len(y)))
# Out:
# 56652137.46140283
# 7526.761419189719

# %% [markdown]
# # Scaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
scaler.transform(X_train)
scaler.transform(X_test)
# Out:
# array([[-0.2956824 , -0.23393904, -0.24653899, ..., -0.07223752,
#          0.66914607,  3.63633625],
#        [-0.30142509, -0.24234929, -0.25376632, ..., -0.75245449,
#         -1.49444202,  0.96489154],
#        [ 2.2141203 , -0.24091513, -0.25253388, ..., -0.75245449,
#         -1.49444202, -1.32491821],
#        ...,
#        [-0.30102516, -0.24176359, -0.253263  , ...,  1.03832079,
#          0.66914607,  0.20162162],
#        [-0.3015282 , -0.2425003 , -0.25389609, ...,  0.48304163,
#         -1.49444202,  0.96489154],
#        [-0.30236771,  1.8343255 , -0.25495264, ..., -0.37764106,
#          0.66914607, -0.94328325]])

# %%
from sklearn.linear_model import Ridge, Lasso, LinearRegression

linreg = LinearRegression().fit(X_train, y_train)
ridge = Ridge(alpha=0.2).fit(X_train, y_train)
lasso = Lasso(alpha=0.2).fit(X_train, y_train)

coefs = pd.DataFrame({
    "coef_linreg": pd.Series(linreg.coef_, index = X.columns),
    "coef_ridge": pd.Series(ridge.coef_, index = X.columns),
    "coef_lasso": pd.Series(lasso.coef_, index= X.columns)})\

coefs\
    .applymap(lambda x: int(x))\
    .style.applymap(lambda x: 'color: red' if x == 0 else 'color: black')
# Out:
# <style type="text/css">
# #T_554e0_row0_col0, #T_554e0_row0_col1, #T_554e0_row0_col2, #T_554e0_row1_col0, #T_554e0_row1_col1, #T_554e0_row1_col2, #T_554e0_row2_col0, #T_554e0_row2_col1, #T_554e0_row2_col2, #T_554e0_row3_col0, #T_554e0_row3_col1, #T_554e0_row3_col2, #T_554e0_row4_col0, #T_554e0_row4_col1, #T_554e0_row4_col2, #T_554e0_row5_col0, #T_554e0_row5_col1, #T_554e0_row5_col2, #T_554e0_row6_col0, #T_554e0_row6_col1, #T_554e0_row6_col2, #T_554e0_row7_col0, #T_554e0_row7_col1, #T_554e0_row7_col2, #T_554e0_row8_col0, #T_554e0_row8_col1, #T_554e0_row8_col2, #T_554e0_row9_col0, #T_554e0_row9_col1, #T_554e0_row9_col2, #T_554e0_row10_col0, #T_554e0_row10_col1, #T_554e0_row10_col2, #T_554e0_row11_col0, #T_554e0_row11_col1, #T_554e0_row11_col2, #T_554e0_row12_col0, #T_554e0_row12_col1, #T_554e0_row12_col2, #T_554e0_row13_col0, #T_554e0_row13_col1, #T_554e0_row13_col2, #T_554e0_row14_col0, #T_554e0_row14_col1, #T_554e0_row14_col2, #T_554e0_row15_col0, #T_554e0_row15_col1, #T_554e0_row15_col2, #T_554e0_row16_col0, #T_554e0_row16_col1, #T_554e0_row16_col2, #T_554e0_row17_col0, #T_554e0_row17_col1, #T_554e0_row17_col2, #T_554e0_row18_col0, #T_554e0_row18_col1, #T_554e0_row18_col2, #T_554e0_row19_col0, #T_554e0_row19_col1, #T_554e0_row19_col2, #T_554e0_row20_col0, #T_554e0_row20_col1, #T_554e0_row20_col2, #T_554e0_row21_col0, #T_554e0_row21_col1, #T_554e0_row21_col2, #T_554e0_row22_col0, #T_554e0_row22_col1, #T_554e0_row22_col2 {
#   color: black;
# }
# </style>
# <table id="T_554e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >coef_linreg</th>
#       <th class="col_heading level0 col1" >coef_ridge</th>
#       <th class="col_heading level0 col2" >coef_lasso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_554e0_level0_row0" class="row_heading level0 row0" >topic_0</th>
#       <td id="T_554e0_row0_col0" class="data row0 col0" >2854</td>
#       <td id="T_554e0_row0_col1" class="data row0 col1" >2803</td>
#       <td id="T_554e0_row0_col2" class="data row0 col2" >2811</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row1" class="row_heading level0 row1" >topic_1</th>
#       <td id="T_554e0_row1_col0" class="data row1 col0" >-6</td>
#       <td id="T_554e0_row1_col1" class="data row1 col1" >-52</td>
#       <td id="T_554e0_row1_col2" class="data row1 col2" >-17</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row2" class="row_heading level0 row2" >topic_2</th>
#       <td id="T_554e0_row2_col0" class="data row2 col0" >-186</td>
#       <td id="T_554e0_row2_col1" class="data row2 col1" >-233</td>
#       <td id="T_554e0_row2_col2" class="data row2 col2" >-202</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row3" class="row_heading level0 row3" >topic_3</th>
#       <td id="T_554e0_row3_col0" class="data row3 col0" >6821</td>
#       <td id="T_554e0_row3_col1" class="data row3 col1" >6765</td>
#       <td id="T_554e0_row3_col2" class="data row3 col2" >6777</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row4" class="row_heading level0 row4" >topic_4</th>
#       <td id="T_554e0_row4_col0" class="data row4 col0" >5871</td>
#       <td id="T_554e0_row4_col1" class="data row4 col1" >5810</td>
#       <td id="T_554e0_row4_col2" class="data row4 col2" >5817</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row5" class="row_heading level0 row5" >topic_5</th>
#       <td id="T_554e0_row5_col0" class="data row5 col0" >-1055</td>
#       <td id="T_554e0_row5_col1" class="data row5 col1" >-1103</td>
#       <td id="T_554e0_row5_col2" class="data row5 col2" >-1081</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row6" class="row_heading level0 row6" >topic_6</th>
#       <td id="T_554e0_row6_col0" class="data row6 col0" >6712</td>
#       <td id="T_554e0_row6_col1" class="data row6 col1" >6649</td>
#       <td id="T_554e0_row6_col2" class="data row6 col2" >6658</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row7" class="row_heading level0 row7" >topic_8</th>
#       <td id="T_554e0_row7_col0" class="data row7 col0" >-738</td>
#       <td id="T_554e0_row7_col1" class="data row7 col1" >-785</td>
#       <td id="T_554e0_row7_col2" class="data row7 col2" >-756</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row8" class="row_heading level0 row8" >topic_9</th>
#       <td id="T_554e0_row8_col0" class="data row8 col0" >3932</td>
#       <td id="T_554e0_row8_col1" class="data row8 col1" >3878</td>
#       <td id="T_554e0_row8_col2" class="data row8 col2" >3886</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row9" class="row_heading level0 row9" >topic_10</th>
#       <td id="T_554e0_row9_col0" class="data row9 col0" >-588</td>
#       <td id="T_554e0_row9_col1" class="data row9 col1" >-635</td>
#       <td id="T_554e0_row9_col2" class="data row9 col2" >-610</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row10" class="row_heading level0 row10" >topic_11</th>
#       <td id="T_554e0_row10_col0" class="data row10 col0" >180</td>
#       <td id="T_554e0_row10_col1" class="data row10 col1" >132</td>
#       <td id="T_554e0_row10_col2" class="data row10 col2" >129</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row11" class="row_heading level0 row11" >topic_12</th>
#       <td id="T_554e0_row11_col0" class="data row11 col0" >-405</td>
#       <td id="T_554e0_row11_col1" class="data row11 col1" >-453</td>
#       <td id="T_554e0_row11_col2" class="data row11 col2" >-429</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row12" class="row_heading level0 row12" >topic_13</th>
#       <td id="T_554e0_row12_col0" class="data row12 col0" >5381</td>
#       <td id="T_554e0_row12_col1" class="data row12 col1" >5324</td>
#       <td id="T_554e0_row12_col2" class="data row12 col2" >5332</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row13" class="row_heading level0 row13" >topic_14</th>
#       <td id="T_554e0_row13_col0" class="data row13 col0" >7476</td>
#       <td id="T_554e0_row13_col1" class="data row13 col1" >7404</td>
#       <td id="T_554e0_row13_col2" class="data row13 col2" >7414</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row14" class="row_heading level0 row14" >topic_15</th>
#       <td id="T_554e0_row14_col0" class="data row14 col0" >713</td>
#       <td id="T_554e0_row14_col1" class="data row14 col1" >664</td>
#       <td id="T_554e0_row14_col2" class="data row14 col2" >666</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row15" class="row_heading level0 row15" >topic_16</th>
#       <td id="T_554e0_row15_col0" class="data row15 col0" >-2777</td>
#       <td id="T_554e0_row15_col1" class="data row15 col1" >-2822</td>
#       <td id="T_554e0_row15_col2" class="data row15 col2" >-2801</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row16" class="row_heading level0 row16" >topic_17</th>
#       <td id="T_554e0_row16_col0" class="data row16 col0" >7469</td>
#       <td id="T_554e0_row16_col1" class="data row16 col1" >7405</td>
#       <td id="T_554e0_row16_col2" class="data row16 col2" >7417</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row17" class="row_heading level0 row17" >topic_18</th>
#       <td id="T_554e0_row17_col0" class="data row17 col0" >1783</td>
#       <td id="T_554e0_row17_col1" class="data row17 col1" >1733</td>
#       <td id="T_554e0_row17_col2" class="data row17 col2" >1737</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row18" class="row_heading level0 row18" >topic_19</th>
#       <td id="T_554e0_row18_col0" class="data row18 col0" >-4707</td>
#       <td id="T_554e0_row18_col1" class="data row18 col1" >-4753</td>
#       <td id="T_554e0_row18_col2" class="data row18 col2" >-4736</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row19" class="row_heading level0 row19" >english</th>
#       <td id="T_554e0_row19_col0" class="data row19 col0" >-2233</td>
#       <td id="T_554e0_row19_col1" class="data row19 col1" >-2232</td>
#       <td id="T_554e0_row19_col2" class="data row19 col2" >-2222</td>
#     </tr>
#     <tr>
#       <th id="T_554e0_level0_row20" class="row_heading level0 row20" >price</th>
#       <td id="T_554e0_row20_col0"

# %% [markdown]
# # Model

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.linear_model import Lasso, LinearRegression
from catboost import CatBoostRegressor

forest = RandomForestRegressor(n_estimators=100, max_leaf_nodes=1000, max_depth=50)
KNN = KNeighborsRegressor(n_neighbors=10)
lasso = Lasso(max_iter=5000,positive=True, fit_intercept=False, )
GBR = GradientBoostingRegressor(
    n_estimators=100, 
    learning_rate=0.1,
    max_depth=3)
SGD = SGDRegressor(max_iter=1000, tol=1e-3)
    
ensemble = StackingRegressor(
    estimators = [('GBR', GBR), ("lasso", lasso), ('forest', forest)],
    final_estimator = GBR,
                n_jobs=-1)

# %%
model  = RandomForestRegressor(
                               bootstrap=True,
                               max_features=0.4,
                               min_samples_leaf=14,
                               n_estimators=100,
                               min_samples_split=14)

# %%
# Add Estimator
pipe = make_pipeline(ensemble)

# Train pipeline
pipe.fit(X_train,y_train)

# Make predictions
#pipe.predict(X_test.iloc[0:2])

# Cross validate pipeline
cross_val_score(ensemble, X_test, y_test, cv=5, scoring='r2').mean()
#cross_val_score(ensemble, X_test, y_test, cv=5, scoring='r2').mean()
# Out:
# 0.2128679773177991

# %%
math.sqrt(32835810)
# Out:
# 5730.2539210754
