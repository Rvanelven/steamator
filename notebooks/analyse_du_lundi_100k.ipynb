# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import numpy as np

# %%
data =pd.read_csv("../raw_data/data_final_indé_big.csv")

# %%
data
# Out:
#        steam_appid                                               name  \
# 0             1002                                   Rag Doll Kung Fu
# 1             1600                                   Dangerous Waters
# 2             1690                                    Space Empires V
# 3             2520                         Gumboy - Crazy Adventures™
# 4             2710                          Act of War: Direct Action
# ...            ...                                                ...
# 22768      1050210                 The Superlatives: Shattered Worlds
# 22769      1050230                                       Dodge Bubble
# 22770      1050240                                           MiniGolf
# 22771      1050470  VR health care (aerobic exercise): VR sport an...
# 22772      1050730                          Uriel’s Chasm 3: Gelshock
#
#                                               top_5_tags   topic_0   topic_1  \
# 0      fighting multiplayer 1980s realistic real_time...  0.016212  0.016212
# 1         strategy simulation naval multiplayer relaxing  0.016555  0.016555
# 2                    strategy 4x space sci_fi turn_based  0.015841  0.015841
# 3      casual singleplayer realistic real_time_with_p...  0.015987  0.015987
# 4                     action strategy rts 1980s relaxing  0.016444  0.016444
# ...                                                  ...       ...       ...
# 22768  adventure rpg text_based realistic real_time_w...  0.016397  0.016397
# 22769             casual action 1980s relaxing realistic  0.015483  0.015483
# 22770          casual mini_golf golf mouse_only relaxing  0.016701  0.016701
# 22771                     sports casual vr vr_only 1980s  0.016183  0.016183
# 22772                   action casual rpg strategy 1980s  0.015605  0.015605
#
#         topic_2   topic_3   topic_4   topic_5   topic_6  ...  english  price  \
# 0      0.016212  0.016212  0.401611  0.016212  0.016212  ...        1   5.99
# 1      0.016555  0.016555  0.016555  0.016555  0.016555  ...        1  22.99
# 2      0.015841  0.015841  0.015841  0.015841  0.015841  ...        1  10.99
# 3      0.015987  0.015987  0.015987  0.015987  0.015987  ...        1   0.00
# 4      0.016444  0.016444  0.016444  0.016444  0.016444  ...        1   1.99
# ...         ...       ...       ...       ...       ...  ...      ...    ...
# 22768  0.016397  0.016397  0.016397  0.445722  0.016397  ...        1   4.79
# 22769  0.015483  0.015483  0.015483  0.015483  0.015483  ...        1   0.79
# 22770  0.211801  0.016701  0.016701  0.016701  0.016701  ...        1   2.99
# 22771  0.016183  0.016183  0.016183  0.016183  0.016183  ...        1  13.49
# 22772  0.015605  0.015605  0.015605  0.703513  0.015605  ...        1   3.99
#
#        days_on_steam  is_a_remake  has_a_website  owner_estimated  \
# 0             4949.0            1              1          22451.0
# 1             4831.0            1              1          56808.0
# 2             4580.0            1              0          60212.0
# 3             4516.0            1              1          53626.0
# 4             4067.0            1              0          29159.0
# ...              ...          ...            ...              ...
# 22768           34.0            1              1            624.0
# 22769           34.0            1              0           4576.0
# 22770           33.0            1              0           1040.0
# 22771           33.0            1              0            208.0
# 22772           33.0            1              0           1248.0
#
#        score_descriptif     ratio  nb_review  sells_per_days
# 0                     9  0.701754         57        4.536472
# 1                     4  0.760870        184       11.759056
# 2                     9  0.692029        276       13.146725
# 3                     7  0.530612         98       11.874668
# 4                     4  0.845070        213        7.169658
# ...                 ...       ...        ...             ...
# 22768                 0  0.666667          3       18.352941
# 22769                 2  0.954545         22      134.588235
# 22770                 5  0.400000          5       31.515152
# 22771                 1  1.000000          1        6.303030
# 22772                 1  1.000000          6       37.818182
#
# [22773 rows x 33 columns]

# %%
data = data[['price', 'days_on_steam', 'topic_19', 'nb_review']]

# %%
data
# Out:
#        price  days_on_steam  topic_19  nb_review
# 0       5.99         4949.0  0.306578         57
# 1      22.99         4831.0  0.016555        184
# 2      10.99         4580.0  0.015841        276
# 3       0.00         4516.0  0.015987         98
# 4       1.99         4067.0  0.016444        213
# ...      ...            ...       ...        ...
# 22768   4.79           34.0  0.016397          3
# 22769   0.79           34.0  0.705831         22
# 22770   2.99           33.0  0.016701          5
# 22771  13.49           33.0  0.016183          1
# 22772   3.99           33.0  0.015605          6
#
# [22773 rows x 4 columns]

# %%
data.corr().style.background_gradient(cmap='coolwarm',text_color_threshold=0.850)
# Out:
# <style type="text/css">
# #T_1765e_row0_col0, #T_1765e_row1_col1, #T_1765e_row2_col2, #T_1765e_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1765e_row0_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1765e_row0_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1765e_row0_col3 {
#   background-color: #b1cbfc;
#   color: #f1f1f1;
# }
# #T_1765e_row1_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1765e_row1_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1765e_row1_col3 {
#   background-color: #92b4fe;
#   color: #f1f1f1;
# }
# #T_1765e_row2_col0, #T_1765e_row2_col1, #T_1765e_row2_col3, #T_1765e_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1765e_row3_col0 {
#   background-color: #afcafc;
#   color: #f1f1f1;
# }
# #T_1765e_row3_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1765e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price</th>
#       <th class="col_heading level0 col1" >days_on_steam</th>
#       <th class="col_heading level0 col2" >topic_19</th>
#       <th class="col_heading level0 col3" >nb_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1765e_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_1765e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1765e_row0_col1" class="data row0 col1" >0.047261</td>
#       <td id="T_1765e_row0_col2" class="data row0 col2" >-0.151891</td>
#       <td id="T_1765e_row0_col3" class="data row0 col3" >0.250251</td>
#     </tr>
#     <tr>
#       <th id="T_1765e_level0_row1" class="row_heading level0 row1" >days_on_steam</th>
#       <td id="T_1765e_row1_col0" class="data row1 col0" >0.047261</td>
#       <td id="T_1765e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1765e_row1_col2" class="data row1 col2" >-0.095222</td>
#       <td id="T_1765e_row1_col3" class="data row1 col3" >0.147960</td>
#     </tr>
#     <tr>
#       <th id="T_1765e_level0_row2" class="row_heading level0 row2" >topic_19</th>
#       <td id="T_1765e_row2_col0" class="data row2 col0" >-0.151891</td>
#       <td id="T_1765e_row2_col1" class="data row2 col1" >-0.095222</td>
#       <td id="T_1765e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1765e_row2_col3" class="data row2 col3" >-0.158291</td>
#     </tr>
#     <tr>
#       <th id="T_1765e_level0_row3" class="row_heading level0 row3" >nb_review</th>
#       <td id="T_1765e_row3_col0" class="data row3 col0" >0.250251</td>
#       <td id="T_1765e_row3_col1" class="data row3 col1" >0.147960</td>
#       <td id="T_1765e_row3_col2" class="data row3 col2" >-0.158291</td>
#       <td id="T_1765e_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.scatter(data.price, data.nb_review)

# %%
plt.scatter(data.days_on_steam, data.nb_review)

# %%
plt.scatter(data.topic_19, data.nb_review)
