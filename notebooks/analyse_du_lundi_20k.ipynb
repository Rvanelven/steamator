# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import numpy as np

# %%
data =pd.read_csv("../raw_data/data_final_indé_small.csv")

# %%
data
# Out:
#        steam_appid                                               name  \
# 0             4290                           RACE: Caterham Expansion
# 1             4900                                      Zen of Sudoku
# 2             7340                                              Azada
# 3             9960                                     Haunted House™
# 4             9970                                       Star Raiders
# ...            ...                                                ...
# 18103      1050210                 The Superlatives: Shattered Worlds
# 18104      1050230                                       Dodge Bubble
# 18105      1050240                                           MiniGolf
# 18106      1050470  VR health care (aerobic exercise): VR sport an...
# 18107      1050730                          Uriel’s Chasm 3: Gelshock
#
#                                               top_5_tags   topic_0   topic_1  \
# 0      racing simulation relaxing realistic real_time...  0.015822  0.015822
# 1                 casual puzzle 1980s relaxing realistic  0.015666  0.307211
# 2                 casual puzzle 1980s relaxing realistic  0.015666  0.307211
# 3      adventure 1980s relaxing realistic real_time_w...  0.015546  0.015546
# 4      action space 1980s realistic real_time_with_pause  0.016158  0.016158
# ...                                                  ...       ...       ...
# 18103  adventure rpg text_based realistic real_time_w...  0.016397  0.016397
# 18104             casual action 1980s relaxing realistic  0.015483  0.015483
# 18105          casual mini_golf golf mouse_only relaxing  0.016701  0.016701
# 18106                     sports casual vr vr_only 1980s  0.016183  0.016183
# 18107                   action casual rpg strategy 1980s  0.015605  0.015605
#
#         topic_2   topic_3   topic_4   topic_5   topic_6  ...  english  price  \
# 0      0.015822  0.015822  0.015822  0.015822  0.015822  ...        1   3.99
# 1      0.015666  0.015666  0.015666  0.015666  0.015666  ...        1   0.00
# 2      0.015666  0.015666  0.015666  0.015666  0.015666  ...        1   6.99
# 3      0.015546  0.015546  0.015546  0.015546  0.015546  ...        1   4.79
# 4      0.016158  0.016158  0.016158  0.016158  0.016158  ...        1   6.99
# ...         ...       ...       ...       ...       ...  ...      ...    ...
# 18103  0.016397  0.016397  0.016397  0.445722  0.016397  ...        1   4.79
# 18104  0.015483  0.015483  0.015483  0.015483  0.015483  ...        1   0.79
# 18105  0.211801  0.016701  0.016701  0.016701  0.016701  ...        1   2.99
# 18106  0.016183  0.016183  0.016183  0.016183  0.016183  ...        1  13.49
# 18107  0.015605  0.015605  0.015605  0.703513  0.015605  ...        1   3.99
#
#        days_on_steam  is_a_remake  has_a_website  owner_estimated  \
# 0             4331.0            1              1           1248.0
# 1             4521.0            1              1          20000.0
# 2             3297.0            1              1           2496.0
# 3             3137.0            1              1           4576.0
# 4             2912.0            1              1           6032.0
# ...              ...          ...            ...              ...
# 18103           34.0            1              1            624.0
# 18104           34.0            1              0           4576.0
# 18105           33.0            1              0           1040.0
# 18106           33.0            1              0            208.0
# 18107           33.0            1              0           1248.0
#
#        score_descriptif     ratio  nb_review  sells_per_days
# 0                     4  0.666667          6        0.288155
# 1                     3  0.877698        139        4.423800
# 2                     1  0.666667         12        0.757052
# 3                     3  0.409091         22        1.458719
# 4                     2  0.172414         29        2.071429
# ...                 ...       ...        ...             ...
# 18103                 0  0.666667          3       18.352941
# 18104                 2  0.954545         22      134.588235
# 18105                 5  0.400000          5       31.515152
# 18106                 1  1.000000          1        6.303030
# 18107                 1  1.000000          6       37.818182
#
# [18108 rows x 33 columns]

# %%
data = data[['price', 'days_on_steam', 'topic_19', 'nb_review']]

# %%
data
# Out:
#        price  days_on_steam  topic_19  nb_review
# 0       3.99         4331.0  0.015822          6
# 1       0.00         4521.0  0.410797        139
# 2       6.99         3297.0  0.410797         12
# 3       4.79         3137.0  0.704628         22
# 4       6.99         2912.0  0.433305         29
# ...      ...            ...       ...        ...
# 18103   4.79           34.0  0.016397          3
# 18104   0.79           34.0  0.705831         22
# 18105   2.99           33.0  0.016701          5
# 18106  13.49           33.0  0.016183          1
# 18107   3.99           33.0  0.015605          6
#
# [18108 rows x 4 columns]

# %%
data.corr().style.background_gradient(cmap='coolwarm',text_color_threshold=0.850)
# Out:
# <style type="text/css">
# #T_8a8ff_row0_col0, #T_8a8ff_row1_col1, #T_8a8ff_row2_col2, #T_8a8ff_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8a8ff_row0_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_8a8ff_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_8a8ff_row0_col3 {
#   background-color: #abc8fd;
#   color: #f1f1f1;
# }
# #T_8a8ff_row1_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8a8ff_row1_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8a8ff_row1_col3 {
#   background-color: #8fb1fe;
#   color: #f1f1f1;
# }
# #T_8a8ff_row2_col0, #T_8a8ff_row2_col1, #T_8a8ff_row2_col3, #T_8a8ff_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8a8ff_row3_col0 {
#   background-color: #a7c5fe;
#   color: #f1f1f1;
# }
# #T_8a8ff_row3_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8a8ff_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price</th>
#       <th class="col_heading level0 col1" >days_on_steam</th>
#       <th class="col_heading level0 col2" >topic_19</th>
#       <th class="col_heading level0 col3" >nb_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a8ff_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_8a8ff_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8a8ff_row0_col1" class="data row0 col1" >0.051251</td>
#       <td id="T_8a8ff_row0_col2" class="data row0 col2" >-0.153288</td>
#       <td id="T_8a8ff_row0_col3" class="data row0 col3" >0.223868</td>
#     </tr>
#     <tr>
#       <th id="T_8a8ff_level0_row1" class="row_heading level0 row1" >days_on_steam</th>
#       <td id="T_8a8ff_row1_col0" class="data row1 col0" >0.051251</td>
#       <td id="T_8a8ff_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8a8ff_row1_col2" class="data row1 col2" >-0.057077</td>
#       <td id="T_8a8ff_row1_col3" class="data row1 col3" >0.124649</td>
#     </tr>
#     <tr>
#       <th id="T_8a8ff_level0_row2" class="row_heading level0 row2" >topic_19</th>
#       <td id="T_8a8ff_row2_col0" class="data row2 col0" >-0.153288</td>
#       <td id="T_8a8ff_row2_col1" class="data row2 col1" >-0.057077</td>
#       <td id="T_8a8ff_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8a8ff_row2_col3" class="data row2 col3" >-0.174595</td>
#     </tr>
#     <tr>
#       <th id="T_8a8ff_level0_row3" class="row_heading level0 row3" >nb_review</th>
#       <td id="T_8a8ff_row3_col0" class="data row3 col0" >0.223868</td>
#       <td id="T_8a8ff_row3_col1" class="data row3 col1" >0.124649</td>
#       <td id="T_8a8ff_row3_col2" class="data row3 col2" >-0.174595</td>
#       <td id="T_8a8ff_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.scatter(data.price, data.nb_review)

# %%
plt.scatter(data.days_on_steam, data.nb_review)

# %%
plt.scatter(data.topic_19, data.nb_review)
