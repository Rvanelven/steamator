# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import numpy as np

# %%
data =pd.read_csv("../raw_data/data_final_indé_medium.csv")

# %%
data
# Out:
#        steam_appid                                               name  \
# 0             1002                                   Rag Doll Kung Fu
# 1             2710                          Act of War: Direct Action
# 2             2720                              ThreadSpace: Hyperbol
# 3             2780                            ARMA: Combat Operations
# 4             2850                                         X: Tension
# ...            ...                                                ...
# 21102      1050210                 The Superlatives: Shattered Worlds
# 21103      1050230                                       Dodge Bubble
# 21104      1050240                                           MiniGolf
# 21105      1050470  VR health care (aerobic exercise): VR sport an...
# 21106      1050730                          Uriel’s Chasm 3: Gelshock
#
#                                               top_5_tags   topic_0   topic_1  \
# ...

# %%
data = data[['price', 'days_on_steam', 'topic_19', 'nb_review']]

# %%
data
# Out:
#        price  days_on_steam  topic_19  nb_review
# 0       5.99         4949.0  0.306578         57
# 1       1.99         4067.0  0.016444        213
# 2       3.99         4311.0  0.269795         40
# 3       5.99         4067.0  0.016200        222
# 4       3.49         3127.0  0.016250         75
# ...      ...            ...       ...        ...
# 21102   4.79           34.0  0.016397          3
# 21103   0.79           34.0  0.705831         22
# 21104   2.99           33.0  0.016701          5
# 21105  13.49           33.0  0.016183          1
# 21106   3.99           33.0  0.015605          6
#
# [21107 rows x 4 columns]

# %%
data.corr().style.background_gradient(cmap='coolwarm',text_color_threshold=0.850)
# Out:
# <style type="text/css">
# #T_e57ff_row0_col0, #T_e57ff_row1_col1, #T_e57ff_row2_col2, #T_e57ff_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e57ff_row0_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e57ff_row0_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e57ff_row0_col3 {
#   background-color: #b2ccfb;
#   color: #f1f1f1;
# }
# #T_e57ff_row1_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e57ff_row1_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e57ff_row1_col3 {
#   background-color: #97b8ff;
#   color: #f1f1f1;
# }
# #T_e57ff_row2_col0, #T_e57ff_row2_col1, #T_e57ff_row2_col3, #T_e57ff_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e57ff_row3_col0 {
#   background-color: #afcafc;
#   color: #f1f1f1;
# }
# #T_e57ff_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e57ff_">
#   <thead>
#     <tr>
# ...

# %%
plt.scatter(data.price, data.nb_review)

# %%
plt.scatter(data.days_on_steam, data.nb_review)

# %%
plt.scatter(data.topic_19, data.nb_review)

# %%
data.to_csv(r'data_final_fat_analyse.csv', index = False)
