# %%
import pandas as pd

# %%
data = pd.read_csv('../raw_data/data_final_indé_medium.csv')
data2 = pd.read_csv('../raw_data/small_followers.csv')

# %%
data.shape
# Out:
# (21107, 37)

# %%
data2.head(5)
# Out:
#    steam_id  followers
# 0      1002        276
# 1      2710       1378
# 2      2720        145
# 3      2780       1023
# 4      2850       1093

# %%
data2 = data2.rename(columns={'steam_id': 'steam_appid'})

# %%
data = data.merge(data2,  on='steam_appid', how='inner')

# %%
data.shape
# Out:
# (3255, 38)

# %%
data.sort_values(by='followers')
# Out:
#       steam_appid                                       name  \
# 2425       364790                          Voyage to Farland
# 1505       329240                        The Weaponographist
# 240         65710                                  Pat & Mat
# 2016       348570             Monster Minis Extreme Off-Road
# 2020       348800                                Chester One
# ...           ...                                        ...
# 1171       312210                              The Fifth Day
# 1412       324510                                  Boundless
# 3028       386590                             Novus Inceptio
# 3202       393080  Call of Duty®: Modern Warfare® Remastered
# 569        269190                           Edge Of Eternity
#
#                                              top_5_tags   topic_0   topic_1  \
# 2425           rogue_like rpg adventure 1980s realistic  0.016323  0.016323
# 1505  rpg action hack_and_slash great_soundtrack rog...  0.016176  0.016176
# 240    cold_war sexual_content casual nudity illuminati  0.016338  0.016338
# 2016         sports racing simulation driving realistic  0.016155  0.016155
# 2020         adventure action platformer retro cartoony  0.427782  0.016662
# ...                                                 ...       ...       ...
# 1171  survival open_world multiplayer post_apocalypt...  0.016056  0.016056
# 1412  sandbox massively_multiplayer open_world craft...  0.015629  0.015629
# 3028     survival open_world sandbox adventure crafting  0.015928  0.015928
# 3202             fps action multiplayer shooter violent  0.015840  0.015840
# 569                rpg jrpg turn_based open_world anime  0.015704  0.015704
#
#        topic_2   topic_3   topic_4   topic_5   topic_6  ...  owner_estimated  \
# 2425  0.016323  0.016323  0.016323  0.016323  0.016323  ...           3386.0
# 1505  0.016176  0.016176  0.016176  0.016176  0.016176  ...          23182.0
# 240   0.016338  0.257131  0.016338  0.016338  0.016338  ...          35308.0
# 2016  0.016155  0.016155  0.016155  0.016155  0.016155  ...             58.0
# 2020  0.016662  0.016662  0.016662  0.016662  0.272294  ...           3386.0
# ...        ...       ...       ...       ...       ...  ...              ...
# 1171  0.016056  0.016056  0.186057  0.016056  0.016056  ...          50000.0
# 1412  0.196877  0.015629  0.015629  0.015629  0.521796  ...          50000.0
# 3028  0.015928  0.015928  0.015928  0.015928  0.697365  ...          50000.0
# 3202  0.015840  0.015840  0.549517  0.015840  0.015840  ...          50000.0
# 569   0.015704  0.015704  0.015704  0.015704  0.015704  ...          41285.0
#
#       score_descriptif     ratio  nb_review  sells_per_days  \
# 2425                 4  0.823529         17        2.369489
# 1505                 6  0.756757         74       15.845523
# 240                  6  0.834270        356       11.393353
# 2016                 5  1.000000          1        0.220532
# 2020                 9  0.941176         17        4.232500
# ...                ...       ...        ...             ...
# 1171                 7  0.454545        869       28.719127
# 1412                 1  0.703478       1639      215.517241
# 3028                 7  0.669989        903       38.343558
# 3202                 5  0.507965       2260       77.760498
# 569                  4  0.822222        495      280.850340
#
#       nb_game_by_publisher  nb_game_by_dev          platforms  indé  followers
# 2425                     1               1  windows;mac;linux     0          0
# 1505                     2               3        windows;mac     0          0
# 240                     23               4            windows     1          0
# 2016                     1               1      windows;linux     0          0
# 2020                     1               1            windows     0          0
# ...                    ...             ...                ...   ...        ...
# 1171                     1               1        windows;mac     0      57097
# 1412                    81               2        windows;mac     1      62499
# 3028                     1               1            windows     0      64116
# 3202                    42               1            windows     1      80291
# 569                     21               1            windows     1      85487
#
# [3255 rows x 38 columns]
