# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import numpy as np

# %%
data =pd.read_csv("../raw_data/data_final_fat.csv")

# %%
data
# Out:
#        steam_appid                                               name  \
# 0               10                                     Counter-Strike
# 1               30                                      Day of Defeat
# 2               50                          Half-Life: Opposing Force
# 3               70                                          Half-Life
# 4               80                     Counter-Strike: Condition Zero
# ...            ...                                                ...
# 26409      1050210                 The Superlatives: Shattered Worlds
# 26410      1050230                                       Dodge Bubble
# 26411      1050240                                           MiniGolf
# 26412      1050470  VR health care (aerobic exercise): VR sport an...
# 26413      1050730                          Uriel’s Chasm 3: Gelshock
#
#                                               top_5_tags   topic_0   topic_1  \
# 0                 action fps multiplayer shooter classic  0.015903  0.015903
# 1            fps world_war_ii multiplayer action shooter  0.015969  0.015969
# 2                 fps action sci_fi singleplayer classic  0.015922  0.015922
# 3                 fps classic action sci_fi singleplayer  0.015922  0.015922
# 4            action fps multiplayer shooter singleplayer  0.015855  0.015855
# ...                                                  ...       ...       ...
# 26409  adventure rpg text_based realistic real_time_w...  0.016397  0.016397
# 26410             casual action 1980s relaxing realistic  0.015483  0.015483
# 26411          casual mini_golf golf mouse_only relaxing  0.016701  0.016701
# 26412                     sports casual vr vr_only 1980s  0.016183  0.016183
# 26413                   action casual rpg strategy 1980s  0.015605  0.015605
#
#         topic_2   topic_3   topic_4   topic_5   topic_6  ...  english  price  \
# 0      0.015903  0.015903  0.697844  0.015903  0.015903  ...        1   7.19
# 1      0.015969  0.015969  0.696585  0.015969  0.015969  ...        1   3.99
# 2      0.015922  0.015922  0.697483  0.015922  0.015922  ...        1   3.99
# 3      0.015922  0.015922  0.697483  0.015922  0.015922  ...        1   7.19
# 4      0.015855  0.015855  0.698752  0.015855  0.015855  ...        1   7.19
# ...         ...       ...       ...       ...       ...  ...      ...    ...
# 26409  0.016397  0.016397  0.016397  0.445722  0.016397  ...        1   4.79
# 26410  0.015483  0.015483  0.015483  0.015483  0.015483  ...        1   0.79
# 26411  0.211801  0.016701  0.016701  0.016701  0.016701  ...        1   2.99
# 26412  0.016183  0.016183  0.016183  0.016183  0.016183  ...        1  13.49
# 26413  0.015605  0.015605  0.015605  0.703513  0.015605  ...        1   3.99
#
#        days_on_steam  is_a_remake  has_a_website  owner_estimated  \
# 0             6755.0            0              0       15000000.0
# 1             5844.0            0              1        7500000.0
# 2             7121.0            0              0        7500000.0
# 3             7479.0            0              1        7500000.0
# 4             5539.0            1              0       15000000.0
# ...              ...          ...            ...              ...
# 26409           34.0            1              1            624.0
# 26410           34.0            1              0           4576.0
# 26411           33.0            1              0           1040.0
# 26412           33.0            1              0            208.0
# 26413           33.0            1              0           1248.0
#
#        score_descriptif     ratio  nb_review  sells_per_days
# 0                     6  0.973888     127873     2220.577350
# 1                     7  0.895648       3814     1283.367556
# 2                     8  0.947996       5538     1053.222862
# 3                    12  0.961878      28855     1002.807862
# 4                     7  0.893871      13559     2708.070049
# ...                 ...       ...        ...             ...
# 26409                 0  0.666667          3       18.352941
# 26410                 2  0.954545         22      134.588235
# 26411                 5  0.400000          5       31.515152
# 26412                 1  1.000000          1        6.303030
# 26413                 1  1.000000          6       37.818182
#
# [26414 rows x 33 columns]

# %%
data = data[['price', 'days_on_steam', 'topic_19', 'nb_review']]

# %%
data
# Out:
#        price  days_on_steam  topic_19  nb_review
# 0       7.19         6755.0  0.015903     127873
# 1       3.99         5844.0  0.015969       3814
# 2       3.99         7121.0  0.015922       5538
# 3       7.19         7479.0  0.015922      28855
# 4       7.19         5539.0  0.015855      13559
# ...      ...            ...       ...        ...
# 26409   4.79           34.0  0.016397          3
# 26410   0.79           34.0  0.705831         22
# 26411   2.99           33.0  0.016701          5
# 26412  13.49           33.0  0.016183          1
# 26413   3.99           33.0  0.015605          6
#
# [26414 rows x 4 columns]

# %%
data.corr().style.background_gradient(cmap='coolwarm',text_color_threshold=0.850)
# Out:
# <style type="text/css">
# #T_ed9ac_row0_col0, #T_ed9ac_row1_col1, #T_ed9ac_row2_col2, #T_ed9ac_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ed9ac_row0_col1, #T_ed9ac_row3_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ed9ac_row0_col2, #T_ed9ac_row2_col0, #T_ed9ac_row2_col1, #T_ed9ac_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ed9ac_row0_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ed9ac_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ed9ac_row1_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ed9ac_row1_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ed9ac_row3_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ed9ac_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed9ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price</th>
#       <th class="col_heading level0 col1" >days_on_steam</th>
#       <th class="col_heading level0 col2" >topic_19</th>
#       <th class="col_heading level0 col3" >nb_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed9ac_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_ed9ac_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ed9ac_row0_col1" class="data row0 col1" >0.067330</td>
#       <td id="T_ed9ac_row0_col2" class="data row0 col2" >-0.157611</td>
#       <td id="T_ed9ac_row0_col3" class="data row0 col3" >0.043020</td>
#     </tr>
#     <tr>
#       <th id="T_ed9ac_level0_row1" class="row_heading level0 row1" >days_on_steam</th>
#       <td id="T_ed9ac_row1_col0" class="data row1 col0" >0.067330</td>
#       <td id="T_ed9ac_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ed9ac_row1_col2" class="data row1 col2" >-0.136585</td>
#       <td id="T_ed9ac_row1_col3" class="data row1 col3" >0.063786</td>
#     </tr>
#     <tr>
#       <th id="T_ed9ac_level0_row2" class="row_heading level0 row2" >topic_19</th>
#       <td id="T_ed9ac_row2_col0" class="data row2 col0" >-0.157611</td>
#       <td id="T_ed9ac_row2_col1" class="data row2 col1" >-0.136585</td>
#       <td id="T_ed9ac_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ed9ac_row2_col3" class="data row2 col3" >-0.023359</td>
#     </tr>
#     <tr>
#       <th id="T_ed9ac_level0_row3" class="row_heading level0 row3" >nb_review</th>
#       <td id="T_ed9ac_row3_col0" class="data row3 col0" >0.043020</td>
#       <td id="T_ed9ac_row3_col1" class="data row3 col1" >0.063786</td>
#       <td id="T_ed9ac_row3_col2" class="data row3 col2" >-0.023359</td>
#       <td id="T_ed9ac_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.scatter(data.price, data.nb_review)

# %%
plt.scatter(data.days_on_steam, data.nb_review)

# %%
plt.scatter(data.topic_19, data.nb_review)

# %%
data.to_csv(r'data_final_fat_analyse.csv', index = False)
